# %%
import math

# Get user input
radius = float(input("Enter the radius of the circle: "))
base = float(input("Enter the base of the triangle: "))
height = float(input("Enter the height of the triangle: "))

# Calculate areas
circle_area = math.pi * radius ** 2
triangle_area = 0.5 * base * height

# Display results in a paragraph
print(f"\nThe area of the circle with radius {radius} is {circle_area:.2f}. "
      f"Meanwhile, the area of the triangle with base {base} and height {height} "
      f"is {triangle_area:.2f}. These values were calculated based on the formulas "
      f"A = πr² for the circle and A = ½ × base × height for the triangle.")
# Out:
# Enter the radius of the circle:  12
# Enter the base of the triangle:  12
# Enter the height of the triangle:  14
# The area of the circle with radius 12.0 is 452.39. Meanwhile, the area of the triangle with base 12.0 and height 14.0 is 84.00. These values were calculated based on the formulas A = πr² for the circle and A = ½ × base × height for the triangle.
